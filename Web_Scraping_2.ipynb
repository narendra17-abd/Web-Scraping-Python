# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
x=requests.get("https://www.timesjobs.com/candidate/job-search.html?searchType=Home_Search&from=submit&asKey=OFF&txtKeywords=&cboPresFuncArea=35")

# %%
soup=BeautifulSoup(x.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head>
# <link href="https://fonts.googleapis.com/css?family=Poppins:400,500,600,700" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/srp-usability.css?v=7.1.7" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://static.timesjobs.com/newtj_js/scripts/tj_scripts/usability/jquery-3.3.1.min.js" type="text/javascript"></script>
# <script src="https://static.timesjobs.com/newtj_js/scripts/jquery.tokeninput.js" type="text/javascript"></script>
# ...

# %%
jobs = soup.find_all('li',class_ ='clearfix job-bx wht-shd-bx')
for job in jobs:
    company_name = job.find('h3',class_ = 'joblist-comp-name').text.replace(' ','')
    skills = job.find('span', class_="srp-skills").text.replace(' ','')
    posted_time = job.find('span', class_="sim-posted").span.text
    print(f'''
Company Name:{company_name}
Required Skills:{skills}
''')
# Out:
# Company Name:
# OrangeBusinessServices
#
#
# Required Skills:
#
# technicalleader,businessrules,xml,systemdevelopment,json,bigdata,rest,javascript,servicenow
#
#
#
#
# Company Name:
# OrangeBusinessServices
#
#
# Required Skills:
#
# technicalleader,businessrules,xml,systemdevelopment,json,bigdata,rest,javascript,servicenow
#
#
#
#
# Company Name:
# krazymantrahrsolutions
#
#
# Required Skills:
#
# adobetargetdevelopment,javascript,jquery,html,css,aem
#
#
#
#
# Company Name:
# krazymantrahrsolutions
#
#
# Required Skills:
#
# angular6,react,corejava,springboot,mysql,css,restapi,html,javascript
#
#
#
#
# Company Name:
# krazymantrahrsolutions
#
#
# Required Skills:
#
# angular6,react,corejava,springboot,mysql,restapi,css,html,javascript
#
#
#
#
# Company Name:
# krazymantrahrsolutions
#
#
# Required Skills:
#
# javaspringbootmicroservicesangular10/12,corejava/j2ee,rabbitmq&jboss,ci/cd,sqlqueriesandmysql,testing,agile(scrum,kanban),designpatterns,hibernate,mvc
#
#
#
#
# Company Name:
# ...

# %%
print(f'''
Company Name:{company_name}
Required Skills:{skills}
''')
print('')
# Out:
# Company Name:
# SolitonTechnologies
#
#
# Required Skills:
#
# .net,c#,javascript,nodejs,angularjs,reactjs,usb,node.js,webtechnologies

# %%
company_name = job.find('h3',class_ = 'joblist-comp-name').text.replace(' ','')

# %%
skills = job.find('span', class_="srp-skills").text.replace(' ','')

# %%
print(skills)
# Out:
# .net,c#,javascript,nodejs,angularjs,reactjs,usb,node.js,webtechnologies

# %%
print(company_name)
# Out:
# SolitonTechnologies

# %%
posted_time = job.find('span', class_="sim-posted").span.text

# %%
print(posted_time)
# Out:
# Posted today

# %%
print(f'''
Company Name:{company_name}
Required Skills:{skills}
Date:{posted_time}
''')
# Out:
# Company Name:
# SolitonTechnologies
#
#
# Required Skills:
#
# .net,c#,javascript,nodejs,angularjs,reactjs,usb,node.js,webtechnologies
#
#
# Date:Posted today
